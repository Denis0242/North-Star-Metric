# %% [markdown]
# # Exploratory Data Analysis
#
# North Star Metric & Product Health analysis notebook.

# %%
import pandas as pd
from pathlib import Path

DATA_PATH = Path('../data/nsm_product_health_data.csv')
df = pd.read_csv(DATA_PATH, parse_dates=['event_date'])
df.head()

# %%
df.describe(include='all')

# %%
df.groupby('experiment_group')[['conversion_rate','d30_retention','churn_rate','revenue_per_user']].mean().round(4)

# %%
df.groupby('segment')[['activation_rate','conversion_rate','d30_retention','churn_rate','engagement_score']].mean().round(4)
